# %%
import numpy as np
import pandas as pd
import tensorflow.keras as K
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    if len(filenames) != 0:
        print(f"Total Files in {dirname}", len(filenames))
# Out:
# Total Files in /kaggle/input/dogs-cats-images/dog vs cat/dataset/training_set/cats 4000
# Total Files in /kaggle/input/dogs-cats-images/dog vs cat/dataset/training_set/dogs 4000
# Total Files in /kaggle/input/dogs-cats-images/dog vs cat/dataset/test_set/cats 1000
# Total Files in /kaggle/input/dogs-cats-images/dog vs cat/dataset/test_set/dogs 1000
# Total Files in /kaggle/input/dogs-cats-images/dataset/training_set/cats 4000
# Total Files in /kaggle/input/dogs-cats-images/dataset/training_set/dogs 4000
# Total Files in /kaggle/input/dogs-cats-images/dataset/test_set/cats 1000
# Total Files in /kaggle/input/dogs-cats-images/dataset/test_set/dogs 1000

# %%
generator = ImageDataGenerator(rescale = 1./255)

train_set = generator.flow_from_directory("../input/dogs-cats-images/dataset/training_set",
                                          class_mode = "binary",
                                          batch_size = 32,
                                          target_size = (224, 224))

val_set = generator.flow_from_directory("../input/dogs-cats-images/dataset/test_set",
                                        batch_size = 32,
                                        class_mode = "binary",
                                        target_size = (224, 224))
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
x_train, y_train = next(train_set)
x_test, y_test = next(val_set)

x_train.shape, y_train.shape
# Out:
# ((32, 224, 224, 3), (32,))

# %%
np.unique(y_train)
# Out:
# array([0., 1.], dtype=float32)

# %%
plt.figure(figsize = (20, 6))

for i in range(5):
    plt.subplot(1, 5, i + 1)
    plt.imshow(train_set[0][0][i])

plt.show()

# %%
from tensorflow.keras.layers import (Conv2D, Activation, BatchNormalization, MaxPooling2D, Dropout, Lambda, AveragePooling2D, 
                                     Dense, Flatten, Input)

CLASSES = 2
EPOCHS = 50
INPUT_SIZE = (224, 224, 3)
EPOCH_STEPS = int(len(train_set) / 32)


def inception_block(x, ft_1x1, ft_3x3_red, ft_3x3, ft_5x5_red, ft_5x5, pool_proj, activation):
    conv_1x1 = Conv2D(ft_1x1, (1, 1), (1, 1), padding='same', activation=activation)(x)
    
    conv_3x3_red = Conv2D(ft_3x3_red, (1, 1), (1, 1), padding='same', activation=activation)(x)
    conv_3x3 = Conv2D(ft_3x3, (3, 3), (1, 1), padding='same', activation=activation)(conv_3x3_red)
    
    conv_5x5_red = Conv2D(ft_5x5_red, (1, 1), (1, 1), padding='same', activation=activation)(x)
    conv_5x5 = Conv2D(ft_5x5, (5, 5), (1, 1), padding='same', activation=activation)(conv_5x5_red)
    
    mx_pool = MaxPooling2D((3, 3), (1, 1), padding='same')(x)
    conv_1x1_pp = Conv2D(pool_proj, (1, 1), (1, 1), padding='same', activation=activation)(mx_pool)
    
    out = K.layers.concatenate([conv_1x1, conv_3x3, conv_5x5, conv_1x1_pp], axis=3)
    
    return out


def side_branch(x, activation, id_):
    avg_pool = AveragePooling2D((5, 5), (3, 3))(x)
    cv_1x1 = Conv2D(128, (1, 1), (1, 1), padding='same')(avg_pool)
    flt = Flatten()(cv_1x1)
    fc = Dense(1000, activation=activation)(flt)
    dp = Dropout(0.4)(fc)
    
    out = Dense(CLASSES, activation='softmax', name=f'softmax{id_}')(dp)
    
    return out


def inception_net(input_size=INPUT_SIZE, activation='relu'):
    LRN = Lambda(tf.nn.local_response_normalization)
    
    inp = Input(shape=input_size)
    model = Conv2D(64, (7, 7), (2, 2), padding='same', input_shape=input_size, activation=activation)(inp)
    model = MaxPooling2D((3, 3), (2, 2), padding='same')(model)
    model = LRN(model)
    model = Conv2D(64, (1, 1), (1, 1), activation=activation)(model)
    model = Conv2D(192, (3, 3), (1, 1), padding='same', activation=activation)(model)
    model = LRN(model)
    model = MaxPooling2D((3, 3), (2, 2), padding='same')(model)
    model = inception_block(model, 64, 96, 128, 16, 32, 32, activation)
    model = inception_block(model, 128, 128, 192, 32, 96, 64, activation)
    model = MaxPooling2D((3, 3), (2, 2), padding='same')(model)
    model = inception_block(model, 192, 96, 208, 16, 48, 64, activation)
    sb0  = side_branch(model, activation, id_=0)
    model = inception_block(model, 160, 112, 224, 24, 64, 64, activation)
    model = inception_block(model, 128, 128, 256, 24, 64, 64, activation)
    model = inception_block(model, 112, 144, 288, 32, 64, 64, activation)
    sb1  = side_branch(model, activation, id_=1)
    model = inception_block(model, 256, 160, 320, 32, 128, 128, activation)
    model = MaxPooling2D((3, 3), (2, 2), padding='same')(model)
    model = inception_block(model, 256, 160, 320, 32, 128, 128, activation)
    model = inception_block(model, 384, 192, 384, 48, 128, 128, activation)
    model = AveragePooling2D((7, 7), (1, 1))(model)
    model = Dropout(0.4)(model)
    model = Flatten()(model)
    model = Dense(1000, activation=activation)(model)
    model = Dense(CLASSES, activation='softmax', name='softmax2')(model)
    
    return K.Model(inputs=inp, outputs=[model, sb0, sb1], name='inception-net-v1')

# %%
icn = inception_net()
icn.compile(
    optimizer='adam', 
    loss="binary_crossentropy", 
    loss_weights={'softmax2': 1.0, 'softmax1': 0.3, 'softmax2': 0.3}, 
    metrics=['accuracy']
)

icn.summary()
# Out:
# Model: "inception-net-v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 multiple             0           max_pooling2d[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   4160        lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0           lambda[1][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 96)   18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 16)   3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 64)   12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 128)  110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 32)   12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 32)   6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 256)  0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 32)   8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 192)  221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 96)   76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 64)   16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 480)  0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 480)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 96)   46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 16)   7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 192)  92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 208)  179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 48)   19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 64)   30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 512)  0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 112)  57456       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 24)   12312       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 160)  82080       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 224)  226016      conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 512)  0           conv2d_22[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 256)  295168      conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 512)  0           conv2d_28[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 144)  73872       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 32)   16416       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 112)  57456       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 288)  373536      conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 528)  0           conv2d_34[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 160)  84640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 32)   16928       concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 528)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 256)  135424      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 320)  461120      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 128)  102528      conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 128)  67712       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 832)  0           conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 160)    133280      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 32)     26656       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 7, 7, 832)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 256)    213248      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 320)    461120      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 128)    102528      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 832)    0           conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 192)    159936      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 48)     39984       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 384)    319872      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 384)    663936      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 128)    153728      conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 1024)   0           conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 4, 4, 512)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 528)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 1024)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 128)    65664       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 4, 4, 128)    67712       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1, 1, 1024)   0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1000)         2049000     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1000)         2049000     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1000)         1025000     flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1000)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1000)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# softmax2 (Dense)                (None, 2)            2002        dense_2[0][0]
# __________________________________________________________________________________________________
# softmax0 (Dense)                (None, 2)            2002        dropout[0][0]
# __________________________________________________________________________________________________
# softmax1 (Dense)                (None, 2)            2002        dropout_1[0][0]
# ==================================================================================================
# Total params: 11,235,934
# Trainable params: 11,235,934
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = icn.fit(
    x_train, [y_train, y_train, y_train],
    validation_data=(x_test, [y_test, y_test, y_test]),
    steps_per_epoch=EPOCH_STEPS,
    epochs=EPOCHS
)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 5s 749ms/step - loss: 1.1120 - softmax2_loss: 0.6932 - softmax0_loss: 0.6960 - softmax1_loss: 0.6935 - softmax2_accuracy: 0.5000 - softmax0_accuracy: 0.5625 - softmax1_accuracy: 0.3750 - val_loss: 1.1092 - val_softmax2_loss: 0.6932 - val_softmax0_loss: 0.6933 - val_softmax1_loss: 0.6932 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.3750
# Epoch 2/50
# 7/7 [==============================] - 4s 633ms/step - loss: 1.1092 - softmax2_loss: 0.6932 - softmax0_loss: 0.6933 - softmax1_loss: 0.6932 - softmax2_accuracy: 0.5625 - softmax0_accuracy: 0.4375 - softmax1_accuracy: 0.6562 - val_loss: 1.1090 - val_softmax2_loss: 0.6932 - val_softmax0_loss: 0.6932 - val_softmax1_loss: 0.6932 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.6250
# Epoch 3/50
# 7/7 [==============================] - 5s 673ms/step - loss: 1.1091 - softmax2_loss: 0.6932 - softmax0_loss: 0.6932 - softmax1_loss: 0.6932 - softmax2_accuracy: 0.5625 - softmax0_accuracy: 0.4688 - softmax1_accuracy: 0.5000 - val_loss: 1.1091 - val_softmax2_loss: 0.6932 - val_softmax0_loss: 0.6932 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.6250
# Epoch 4/50
# 7/7 [==============================] - 5s 668ms/step - loss: 1.1091 - softmax2_loss: 0.6931 - softmax0_loss: 0.6932 - softmax1_loss: 0.6932 - softmax2_accuracy: 0.4062 - softmax0_accuracy: 0.6875 - softmax1_accuracy: 0.5312 - val_loss: 1.1091 - val_softmax2_loss: 0.6932 - val_softmax0_loss: 0.6932 - val_softmax1_loss: 0.6932 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.6250
# Epoch 5/50
# 7/7 [==============================] - 4s 640ms/step - loss: 1.1091 - softmax2_loss: 0.6931 - softmax0_loss: 0.6932 - softmax1_loss: 0.6932 - softmax2_accuracy: 0.4688 - softmax0_accuracy: 0.4062 - softmax1_accuracy: 0.3125 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6932 - val_softmax1_loss: 0.6932 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.6250
# Epoch 6/50
# 7/7 [==============================] - 4s 631ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6932 - softmax1_loss: 0.6932 - softmax2_accuracy: 0.6250 - softmax0_accuracy: 0.5625 - softmax1_accuracy: 0.4688 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.3750
# Epoch 7/50
# 7/7 [==============================] - 4s 630ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5000 - softmax0_accuracy: 0.6562 - softmax1_accuracy: 0.4688 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.3750 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.6250
# Epoch 8/50
# 7/7 [==============================] - 4s 642ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6932 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.3438 - softmax0_accuracy: 0.5000 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6932 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.3750
# Epoch 9/50
# 7/7 [==============================] - 4s 609ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6932 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4688 - softmax0_accuracy: 0.5938 - softmax1_accuracy: 0.5312 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.6250
# Epoch 10/50
# 7/7 [==============================] - 4s 623ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5938 - softmax0_accuracy: 0.4375 - softmax1_accuracy: 0.5312 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.5938 - val_softmax1_accuracy: 0.6250
# Epoch 11/50
# 7/7 [==============================] - 4s 619ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4062 - softmax0_accuracy: 0.3750 - softmax1_accuracy: 0.4062 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.3750
# Epoch 12/50
# 7/7 [==============================] - 4s 622ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4375 - softmax0_accuracy: 0.5625 - softmax1_accuracy: 0.5312 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.6250
# Epoch 13/50
# 7/7 [==============================] - 4s 631ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.6562 - softmax0_accuracy: 0.5312 - softmax1_accuracy: 0.4688 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.6250
# Epoch 14/50
# 7/7 [==============================] - 5s 690ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.3750 - softmax0_accuracy: 0.5625 - softmax1_accuracy: 0.5625 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.3750
# Epoch 15/50
# 7/7 [==============================] - 5s 670ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5625 - softmax0_accuracy: 0.5000 - softmax1_accuracy: 0.4062 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.7188 - val_softmax1_accuracy: 0.6250
# Epoch 16/50
# 7/7 [==============================] - 5s 643ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5000 - softmax0_accuracy: 0.5312 - softmax1_accuracy: 0.6250 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.3750
# Epoch 17/50
# 7/7 [==============================] - 4s 626ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5312 - softmax0_accuracy: 0.4375 - softmax1_accuracy: 0.4375 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6875 - val_softmax1_accuracy: 0.6250
# Epoch 18/50
# 7/7 [==============================] - 4s 633ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4375 - softmax0_accuracy: 0.6562 - softmax1_accuracy: 0.3750 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6562 - val_softmax1_accuracy: 0.3750
# Epoch 19/50
# 7/7 [==============================] - 4s 615ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5938 - softmax0_accuracy: 0.6875 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.3750
# Epoch 20/50
# 7/7 [==============================] - 4s 640ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4062 - softmax0_accuracy: 0.6875 - softmax1_accuracy: 0.6250 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.6250
# Epoch 21/50
# 7/7 [==============================] - 4s 623ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5000 - softmax0_accuracy: 0.6562 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.6250
# Epoch 22/50
# 7/7 [==============================] - 4s 637ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5312 - softmax0_accuracy: 0.4062 - softmax1_accuracy: 0.4688 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.6250
# Epoch 23/50
# 7/7 [==============================] - 4s 627ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4062 - softmax0_accuracy: 0.5625 - softmax1_accuracy: 0.4062 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.3750
# Epoch 24/50
# 7/7 [==============================] - 4s 618ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4688 - softmax0_accuracy: 0.4062 - softmax1_accuracy: 0.5625 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.6250
# Epoch 25/50
# 7/7 [==============================] - 4s 622ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5312 - softmax0_accuracy: 0.5000 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.3750
# Epoch 26/50
# 7/7 [==============================] - 5s 651ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5625 - softmax0_accuracy: 0.4375 - softmax1_accuracy: 0.3438 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.3750 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.6250
# Epoch 27/50
# 7/7 [==============================] - 5s 643ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.3750 - softmax0_accuracy: 0.6250 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.3750 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.3750
# Epoch 28/50
# 7/7 [==============================] - 4s 620ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5938 - softmax0_accuracy: 0.4375 - softmax1_accuracy: 0.4688 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.3750 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.6250
# Epoch 29/50
# 7/7 [==============================] - 4s 632ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4375 - softmax0_accuracy: 0.4375 - softmax1_accuracy: 0.5625 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.5312 - val_softmax1_accuracy: 0.3750
# Epoch 30/50
# 7/7 [==============================] - 4s 614ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5625 - softmax0_accuracy: 0.4688 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6562 - val_softmax1_accuracy: 0.6250
# Epoch 31/50
# 7/7 [==============================] - 4s 624ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.6250 - softmax0_accuracy: 0.5312 - softmax1_accuracy: 0.7188 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6875 - val_softmax1_accuracy: 0.3750
# Epoch 32/50
# 7/7 [==============================] - 4s 623ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5938 - softmax0_accuracy: 0.5625 - softmax1_accuracy: 0.5625 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.6250
# Epoch 33/50
# 7/7 [==============================] - 4s 628ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5625 - softmax0_accuracy: 0.4688 - softmax1_accuracy: 0.4375 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.5938 - val_softmax1_accuracy: 0.6250
# Epoch 34/50
# 7/7 [==============================] - 4s 616ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.3750 - softmax0_accuracy: 0.4062 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.3750 - val_softmax1_accuracy: 0.3750
# Epoch 35/50
# 7/7 [==============================] - 4s 616ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.3125 - softmax0_accuracy: 0.5625 - softmax1_accuracy: 0.4688 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.6250
# Epoch 36/50
# 7/7 [==============================] - 4s 623ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.6250 - softmax0_accuracy: 0.4375 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.4062 - val_softmax1_accuracy: 0.3750
# Epoch 37/50
# 7/7 [==============================] - 4s 614ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5312 - softmax0_accuracy: 0.5312 - softmax1_accuracy: 0.5312 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.4375 - val_softmax1_accuracy: 0.6250
# Epoch 38/50
# 7/7 [==============================] - 5s 656ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.7188 - softmax0_accuracy: 0.3750 - softmax1_accuracy: 0.5312 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.3750
# Epoch 39/50
# 7/7 [==============================] - 5s 650ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4688 - softmax0_accuracy: 0.5312 - softmax1_accuracy: 0.5312 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.4375 - val_softmax1_accuracy: 0.6250
# Epoch 40/50
# 7/7 [==============================] - 4s 632ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4375 - softmax0_accuracy: 0.5938 - softmax1_accuracy: 0.5625 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6875 - val_softmax1_accuracy: 0.3750
# Epoch 41/50
# 7/7 [==============================] - 4s 629ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4062 - softmax0_accuracy: 0.4688 - softmax1_accuracy: 0.5625 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6562 - val_softmax1_accuracy: 0.4688
# Epoch 42/50
# 7/7 [==============================] - 4s 626ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4375 - softmax0_accuracy: 0.5312 - softmax1_accuracy: 0.5938 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.6250
# Epoch 43/50
# 7/7 [==============================] - 4s 624ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4688 - softmax0_accuracy: 0.4688 - softmax1_accuracy: 0.5625 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.4062 - val_softmax1_accuracy: 0.6250
# Epoch 44/50
# 7/7 [==============================] - 4s 624ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4688 - softmax0_accuracy: 0.5312 - softmax1_accuracy: 0.4062 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.4062 - val_softmax1_accuracy: 0.6250
# Epoch 45/50
# 7/7 [==============================] - 4s 633ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5000 - softmax0_accuracy: 0.5000 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.5312 - val_softmax1_accuracy: 0.3750
# Epoch 46/50
# 7/7 [==============================] - 4s 614ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4375 - softmax0_accuracy: 0.6562 - softmax1_accuracy: 0.6562 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.6250 - val_softmax1_accuracy: 0.6250
# Epoch 47/50
# 7/7 [==============================] - 4s 630ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5312 - softmax0_accuracy: 0.4688 - softmax1_accuracy: 0.4375 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.5000 - val_softmax1_accuracy: 0.3750
# Epoch 48/50
# 7/7 [==============================] - 4s 614ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.5312 - softmax0_accuracy: 0.4375 - softmax1_accuracy: 0.5000 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.5938 - val_softmax1_accuracy: 0.6250
# Epoch 49/50
# 7/7 [==============================] - 4s 626ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.3125 - softmax0_accuracy: 0.3750 - softmax1_accuracy: 0.4375 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.4062 - val_softmax1_accuracy: 0.3750
# Epoch 50/50
# 7/7 [==============================] - 5s 646ms/step - loss: 1.1090 - softmax2_loss: 0.6931 - softmax0_loss: 0.6931 - softmax1_loss: 0.6931 - softmax2_accuracy: 0.4688 - softmax0_accuracy: 0.3438 - softmax1_accuracy: 0.6250 - val_loss: 1.1090 - val_softmax2_loss: 0.6931 - val_softmax0_loss: 0.6931 - val_softmax1_loss: 0.6931 - val_softmax2_accuracy: 0.6250 - val_softmax0_accuracy: 0.4375 - val_softmax1_accuracy: 0.6250

# %%
def show_train_history(history, xlabel, ylabel, train, suffix):
    for item in train:
        plt.plot(history[item + '_' + suffix])

    plt.title('Train History')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend(train, loc='upper left')
    plt.show()

# %%
history_all = history.history
history_all.keys()
# Out:
# dict_keys(['loss', 'softmax2_loss', 'softmax0_loss', 'softmax1_loss', 'softmax2_accuracy', 'softmax0_accuracy', 'softmax1_accuracy', 'val_loss', 'val_softmax2_loss', 'val_softmax0_loss', 'val_softmax1_loss', 'val_softmax2_accuracy', 'val_softmax0_accuracy', 'val_softmax1_accuracy'])

# %%
show_train_history(history_all, 'Epoch', 'Accuracy', ('softmax2', 'softmax1', 'softmax0'), 'accuracy')

# %%
show_train_history(history_all, 'Epoch', 'Loss', ('softmax2', 'softmax1', 'softmax0'), suffix='loss')
